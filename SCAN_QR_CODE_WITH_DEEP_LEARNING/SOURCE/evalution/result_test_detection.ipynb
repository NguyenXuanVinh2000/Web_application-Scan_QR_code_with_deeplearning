# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# #Tao file test.txt de danh gia

# %%
# %cd /content/
# Out:
# /content

# %%
import zipfile 
import glob  
from skimage.io import imread  
from skimage.transform import resize  

img_list_test = sorted(glob.glob('/content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/Data/testset/*.JPG'))

# %%
len(img_list_test)
# Out:
# 796

# %%
def write(my_list):
  with open('/content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation/darknet/test.txt', 'w') as f:
    for item in my_list:
        f.write("%s\n" % item)

# %%
write(img_list_test)

# %% [markdown]
# Sửa lại trong file yolo.data trong darknet_lan2 valid=val.txt thành valid=test.txt

# %%
# %cd /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation
# !git clone https://github.com/AlexeyAB/darknet
# %cd /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation/darknet
# Out:
# /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation
# Cloning into 'darknet'...
# remote: Enumerating objects: 15424, done.
# remote: Counting objects: 100% (1/1), done.
# remote: Total 15424 (delta 0), reused 1 (delta 0), pack-reused 15423
# Receiving objects: 100% (15424/15424), 14.06 MiB | 7.75 MiB/s, done.
# Resolving deltas: 100% (10362/10362), done.
# Checking out files: 100% (2050/2050), done.
# /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation/darknet

# %% [markdown]
# #Tinh mAp theo IoU

# %%
# %cd /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation/darknet
# !rm darknet
# !make
# Out:
# /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation/darknet
# chmod +x *.sh
# ...

# %% [markdown]
# ##Yolov3

# %%
# %cd /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation/darknet
# !./darknet detector map yolo.data cfg/yolov3.cfg backup/yolov3_final.weights -iou_thresh 0.5
# Out:
# /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation/darknet
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %%
# Tính mAP với Iou 0.75%
# %cd /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation/darknet
# !./darknet detector map yolo.data cfg/yolov3.cfg backup/yolov3_final.weights -iou_thresh 0.75
# Out:
# /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation/darknet
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
#    3 conv     64       3 x 3/ 1    208 x 208 x  32 ->  208 x 208 x  64 1.595 BF
#    4 Shortcut Layer: 1,  wt = 0, wn = 0, outputs: 208 x 208 x  64 0.003 BF
#    5 conv    128       3 x 3/ 2    208 x 208 x  64 ->  104 x 104 x 128 1.595 BF
# ...

# %% [markdown]
# ##Yolov4 tiny

# %%
# %cd /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation/darknet
# !./darknet detector map yolo.data cfg/yolov4-tiny-custom.cfg backup/yolov4-tiny-custom_last.weights -iou_thresh 0.5
# Out:
# /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation/darknet
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
# ...

# %%
# %cd /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation/darknet
# !./darknet detector map yolo.data cfg/yolov4-tiny-custom.cfg backup/yolov4-tiny-custom_last.weights -iou_thresh 0.75
# Out:
# /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation/darknet
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 8, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 2    416 x 416 x   3 ->  208 x 208 x  32 0.075 BF
#    1 conv     64       3 x 3/ 2    208 x 208 x  32 ->  104 x 104 x  64 0.399 BF
#    2 conv     64       3 x 3/ 1    104 x 104 x  64 ->  104 x 104 x  64 0.797 BF
#    3 route  2 		                       1/2 ->  104 x 104 x  32
#    4 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    5 conv     32       3 x 3/ 1    104 x 104 x  32 ->  104 x 104 x  32 0.199 BF
#    6 route  5 4 	                           ->  104 x 104 x  64
# ...

# %% [markdown]
# #Yolov4

# %%
# %cd /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation/darknet
# !./darknet detector map yolo.data cfg/yolov4-custom.cfg backup/yolov4-custom_last.weights -iou_thresh 0.5
# Out:
# /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation/darknet
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
# ...

# %%
# %cd /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation/darknet
# !./darknet detector map yolo.data cfg/yolov4-custom.cfg backup/yolov4-custom_last.weights -iou_thresh 0.75
# Out:
# /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/evaluation/darknet
#  CUDA-version: 11010 (11020), cuDNN: 7.6.5, CUDNN_HALF=1, GPU count: 1
#  CUDNN_HALF=1
#  OpenCV version: 3.2.0
#  0 : compute_capability = 750, cudnn_half = 1, GPU: Tesla T4
# net.optimized_memory = 0
# mini_batch = 1, batch = 16, time_steps = 1, train = 0
#    layer   filters  size/strd(dil)      input                output
#    0 Create CUDA-stream - 0
#  Create cudnn-handle 0
# conv     32       3 x 3/ 1    416 x 416 x   3 ->  416 x 416 x  32 0.299 BF
#    1 conv     64       3 x 3/ 2    416 x 416 x  32 ->  208 x 208 x  64 1.595 BF
#    2 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    3 route  1 		                           ->  208 x 208 x  64
#    4 conv     64       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  64 0.354 BF
#    5 conv     32       1 x 1/ 1    208 x 208 x  64 ->  208 x 208 x  32 0.177 BF
# ...

# %% [markdown]
# ##Yolov5

# %%
# !git clone https://github.com/ultralytics/yolov5  # clone
# %cd yolov5
# %pip install -qr requirements.txt  # install

import torch
import utils
display = utils.notebook_init()  # checks
# Out:
# YOLOv5 🚀 v6.1-263-g0537e8d Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
# Setup complete ✅ (2 CPUs, 12.7 GB RAM, 38.7/78.2 GB disk)

# %%
# !python /content/yolov5/val.py --weights /content/best.pt --data /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/Yolov5/yolov5/custum_dataset.yaml --img 416 --iou 0.5 --half
# Out:
# val: data=/content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/Yolov5/yolov5/custum_dataset.yaml, weights=['/content/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.5, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v6.1-263-g0537e8d Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# custom_model summary: 213 layers, 7012822 parameters, 0 gradients
# ...
# 100% 755k/755k [00:00<00:00, 16.6MB/s]
# val: Scanning '/content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/Yolov5/labels/test' images and labels...796 found, 0 missing, 0 empty, 1 corrupt: 100% 796/796 [02:27<00:00,  5.41it/s]
# val: WARNING: /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/Yolov5/images/test/1741.JPG: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0119]
# ...

# %%
# !python /content/yolov5/val.py --weights /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/Yolov5/yolov5/custom_model4/weights/best.pt --data /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/Yolov5/yolov5/custum_dataset.yaml --img 416 --iou 0.75 --half
# Out:
# val: data=/content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/Yolov5/yolov5/custum_dataset.yaml, weights=['/content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/Yolov5/yolov5/custom_model4/weights/best.pt'], batch_size=32, imgsz=416, conf_thres=0.001, iou_thres=0.75, task=val, device=, workers=8, single_cls=False, augment=False, verbose=False, save_txt=False, save_hybrid=False, save_conf=False, save_json=False, project=runs/val, name=exp, exist_ok=False, half=True, dnn=False
# YOLOv5 🚀 v6.1-263-g0537e8d Python-3.7.13 torch-1.11.0+cu113 CUDA:0 (Tesla T4, 15110MiB)
#
# Fusing layers...
# custom_model summary: 213 layers, 7012822 parameters, 0 gradients
# val: Scanning '/content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/Yolov5/labels/test.cache' images and labels... 796 found, 0 missing, 0 empty, 1 corrupt: 100% 796/796 [00:00<?, ?it/s]
# val: WARNING: /content/drive/MyDrive/KHOA_LUAN_TOT_NGHIEP/Yolov5/images/test/1741.JPG: ignoring corrupt image/label: non-normalized or out of bounds coordinates [     1.0119]
# ...
